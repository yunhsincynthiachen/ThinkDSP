# %%
import thinkdsp
import thinkplot

# %%
cos_sig = thinkdsp.CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = thinkdsp.SinSignal(freq=880, amp=0.5, offset=0)

# %%
cos_sig.plot()

# %%
sin_sig.plot()

# %%
mix = sin_sig + cos_sig
mix

# %%
wave = mix.make_wave(duration=0.5, start=0, framerate=11025)
wave

# %%
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print 'Number of samples', len(wave.ys)
print 'Timestep in ms', 1.0 / 11025 * 1000
# Out:
# Number of samples 5513
# Timestep in ms 0.0907029478458

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*3)

# %%
segment.plot()

# %%
wave.normalize()
wave.apodize()
wave.plot()

# %%
filename = 'temp.wav'
wave.write('temp.wav')
# Out:
# Writing temp.wav

# %%
thinkdsp.play_wave(filename='temp.wav', player='aplay')

# %%
reload(thinkdsp)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
 wave = thinkdsp.read_wave('75341__neotone__cymbol-scraped.wav')
 wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start = 0.5000000000000000000005
duration = 0.500000000000000005
segment = wave.segment(start, duration)
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = segment.make_spectrum()

# %%
spectrum.plot()

# %%
spectrum.low_pass(1000)

# %%
spectrum.plot()

# %%
filtered = spectrum.make_wave()
filtered.plot()

# %%
filtered.normalize()
filtered.plot()

# %%
segment.apodize()
segment.plot()

# %%
filtered.apodize()
filtered.plot()

# %%
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filtered.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
